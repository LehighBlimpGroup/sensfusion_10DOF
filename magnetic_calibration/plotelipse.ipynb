# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-poster')

# %%
# fig = plt.figure(figsize = (10,10))
# ax = plt.axes(projection='3d')  
magAccel= np.loadtxt('data.csv', delimiter=',')#manxyz#magAccel400x
mag=magAccel[:,0:3]
offsets = np.array([36.72,    -43.69,    -93.96])

mag = np.subtract(mag, offsets).T
norms = np.linalg.norm(mag, axis=0)
print((max(norms)-min(norms))*len(norms)/sum(norms))
print(np.shape(mag))
x = mag[0]#np.random.random(50)
y = mag[1]#np.random.random(50)
z = mag[2]#np.random.random(50)

fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
ax.grid()

ax.scatter(x[0:400], y[0:400], z[0:400], c = 'r', s = 50)
ax.scatter(x[400:], y[400:], z[400:], c = 'g', s = 50)
ax.set_title('3D Scatter Plot')

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('z', labelpad=20)

plt.show()
# Out:
# 0.6793653635063306
# (3, 844)

# %%
magAccel= np.loadtxt('data.csv', delimiter=',')#manxyz#magAccel400x
mag=magAccel[:,0:3]



offsets = np.array([36.72,    -43.69,    -93.96])
transform  = np.array([[1.0000,   38.4712,   -4.7550],
    [37.5602,   -0.4242,    3.7754],
    [ 2.5122,    1.1394,  -39.2638]])

newmag = transform.dot(np.subtract(mag, offsets).T)#transform.dot(np.array([mag[i, :] - offsets for i in range(mag.shape[1])]))
norms = np.linalg.norm(newmag, axis=0)
print((max(norms)-min(norms))*len(norms)/sum(norms))
x = newmag[0]#np.random.random(50)
y = newmag[1]#np.random.random(50)
z = newmag[2]#np.random.random(50)

fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
ax.grid()

ax.scatter(x[0:400], y[0:400], z[0:400], c = 'r', s = 50)
ax.scatter(x[400:], y[400:], z[400:], c = 'g', s = 50)
ax.set_title('3D Scatter Plot')

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('z', labelpad=20)

plt.show()
# Out:
# 0.6528365198097779
